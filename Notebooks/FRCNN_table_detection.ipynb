# %%
# !git clone https://github.com/you359/Keras-FasterRCNN.git
# Out:
# Cloning into 'Keras-FasterRCNN'...
# remote: Enumerating objects: 152, done.
# remote: Counting objects: 100% (152/152), done.
# remote: Compressing objects: 100% (84/84), done.
# remote: Total 152 (delta 66), reused 138 (delta 63), pack-reused 0
# Receiving objects: 100% (152/152), 2.19 MiB | 30.79 MiB/s, done.
# Resolving deltas: 100% (66/66), done.

# %%
# !ls
# Out:
# data  Keras-FasterRCNN	sample_data

# %%
# %cd /content/Keras-FasterRCNN
# Out:
# /content/Keras-FasterRCNN

# %%
# !ls
# Out:
# images	     LICENSE	     README.md	       results_imgs   train_frcnn.py
# keras_frcnn  measure_map.py  requirements.txt  test_frcnn.py  transfer

# %%
# !pip install -r requirements.txt
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 377.1 MB 9.5 kB/s
# ...

# %%
# !python train_frcnn.py -o simple -p /content/train_annotations.txt --num_epochs 20
# Out:
# Using TensorFlow backend.
# Parsing annotation files
# Training images per class:
# {'Table': 555, 'bg': 0}
# Num classes (including bg) = 2
# Config has been written to config.pickle, and can be loaded when testing to ensure correct results
# Num train samples 252
# Num test samples 48
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/keras/backend/tensorflow_backend.py:47: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/keras/backend/tensorflow_backend.py:351: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/keras/backend/tensorflow_backend.py:3176: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# ...

# %%
# !python test_frcnn.py -p /content/data/Images/test/
# Out:
# Using TensorFlow backend.
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/keras/backend/tensorflow_backend.py:121: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# {0: 'Table', 1: 'bg'}
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/keras/backend/tensorflow_backend.py:351: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/keras/backend/tensorflow_backend.py:3176: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/keras/backend/tensorflow_backend.py:3043: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# ...

# %%
from google.colab import files
files.download("model_frcnn.hdf5")
